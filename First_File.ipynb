# %%
# This is a new test project

#This is our code

print("lavie est dure sans confiture!")

# This is a change to our code

print("I love merging and branching!")
